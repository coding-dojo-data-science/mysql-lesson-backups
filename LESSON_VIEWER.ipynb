# %% [markdown]
# # Lesson Viewer

# %%
from IPython.display import Markdown,HTML,display

# %%
with open("1_my_sql_workbench.md") as f:
	display(HTML(f.read()))
# Out:
# <h1>MySQL Workbench</h1>
# <h2>Objectives:</h2>
# <ol><li>Introduction to MySQL Workbench</li><li>Make first queries in MySQL workbench</li></ol>
# <h2>What is MySQL Workbench?</h2>
# <p>
#  MySQL Workbench is just a Graphical User Interface (GUI) for us to interact with <strong>MySQL</strong>, one of the most popular relational databases in the world - through SQL commands. It is not necessary to use a GUI. We could interact with our MySQL databases through the terminal, but the GUI makes it much easier to see our data and create new databases.</p>
# <h2>Why MySQL Workbench?</h2>
# <p>
#  We use MySQL Workbench when we are interacting with our databases because it allow us to directly make SQL queries. It also has a great interface where we can map out our tables and establish relationships between them.</p>
# ...

# %%
with open("2_reverse_engineering.md") as f:
	display(HTML(f.read()))
# Out:
# <h1>Reverse Engineering</h1><h2>Lesson Objectives:</h2><ul><li>Understand what reverse engineering is and how to do it in MySQL Workbench</li><li>Explore an ERD to understand how a database is designed</li></ul><p>This lesson uses the "world" database that you loaded into MySQL Workbench in the previous lesson.  We are going to create a visual representation of the database, known as an ERD (Entity Relationship Diagram).  We are doing this early in the week because the ERD can help you understand how a database is constructed which makes querying it easier.<br></p><h2>What is an Entity Relationship Diagram?</h2>
# ...

# %%
with open("3_sql_basic_queries.md") as f:
	display(HTML(f.read()))
# Out:
# <h1>SQL Basic Queries</h1><p>You have had some practice with basic SQL queries using SQL Alchemy within Python from week 12 of the course. We are going to review the basics of SQL queries and give you a chance to practice these in the MySQL Workbench interface.  </p><p>For additional practice, we recommend trying the tutorials and quizzes found <a href="https://sqlzoo.net/wiki/SQL_Tutorial" target="_blank">here</a>.</p>
# <h2>Objectives:</h2>
# <ul><li>Apply basic SQL queries using:  SELECT, FROM, LIMIT, ORDER BY, DISTINCT, WHERE,  GROUP BY, AS, HAVING</li><li>Apply SQL Aggregate Functions</li></ul>
# <p><br></p>
# <figure><img src="data:image/png;base64,..."></figure>
# <p><br></p>
# ...
